# %% [markdown]
# # Примеры структур со словарями

# %% [markdown]
# ### **`Список всех ключей - итерация`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
for key in names_marks.keys():
    print(key)
# Out:
# Андрей
# Кристина
# Дмитрий
# Владислав
# Максим

# %% [markdown]
# ### **`Список всех занчений - итерация`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
for val in names_marks.values():
    print(val)
# Out:
# 5
# 4
# 5
# 3
# 5

# %% [markdown]
# ### **`Список пары (ключ, значение) - итерация`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
for key, val in names_marks.items():
    print(f"{key}: {val}")
# Out:
# Андрей: 5
# Кристина: 4
# Дмитрий: 5
# Владислав: 3
# Максим: 5

# %% [markdown]
# ### **`Получение значения по ключу`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
print(names_marks["Андрей"])
# Out:
# 5

# %% [markdown]
# ### **`Добавить или обновить ключ`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
names_marks["Алексей"] = 4
for key, val in names_marks.items():
    print(f"{key}: {val}")
# Out:
# Андрей: 5
# Кристина: 4
# Дмитрий: 5
# Владислав: 3
# Максим: 5
# Алексей: 4

# %% [markdown]
# ### **`Удалить ключ`**

# %%
names_marks = {"Андрей": 5, "Кристина": 4, "Дмитрий": 5, "Владислав": 3, "Максим": 5}
del names_marks["Владислав"]
for key, val in names_marks.items():
    print(f"{key}: {val}")
# Out:
# Андрей: 5
# Кристина: 4
# Дмитрий: 5
# Максим: 5
